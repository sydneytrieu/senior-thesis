# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

# %%
rso_data = pd.read_csv('C:\\Users\\scher\\school\\senior-thesis\\data\\rso_data_v2.txt', index_col=0)

# %%
rso_data
# Out:
#       Year                                Organization  Type  \
# 0     2012                            maganda magazine   PUB
# 1     2012                                     Threads   PUB
# 2     2012                          Alternative Breaks   PUB
# 3     2012                               BARE Magazine   PUB
# 4     2012                     Berkeley Fiction Review   PUB
# ...    ...                                         ...   ...
# 3874  2020  Volunteer Health Interpreters Organization  SISG
# 3875  2020     Volunteer Income Tax Assistance Program  SISG
# 3876  2020     Volunteers Around the World at Berkeley  SISG
# 3877  2020                                 Wonderworks  SISG
# 3878  2020                               You Mean More  SISG
#
#                 Designation  Standing  Allocation
# 0          Publications RSO        23     1592.02
# 1          Publications RSO        12     1300.00
# 2               Service RSO        10      891.07
# 3          Publications RSO         6     1250.00
# 4          Publications RSO        29     1036.99
# ...                     ...       ...         ...
# 3874  Health & Wellness RSO        15     4300.00
# 3875            Service RSO         8      480.00
# 3876            Service RSO         7      250.00
# 3877            Service RSO        10        0.00
# 3878  Health & Wellness RSO         9     1200.00
#
# [3876 rows x 6 columns]

# %% [markdown]
# # Group levels of `Standing`

# %% [markdown]
# To start, we'll examine the `Standing` column for the 2019-2020 budget year.

# %%
rso_2019 = rso_data[rso_data['Year'] == 2019]

# %%
sns.set(rc={'figure.figsize':(20,8)})

fig, ax = plt.subplots(1,2)

sns.boxplot(x='Standing', data=rso_2019, ax=ax[0]).set_title('Boxplot of Standing for 2019-2020')
sns.distplot(rso_2019['Standing'], bins=np.arange(135), ax=ax[1]).set_title('Histogram of Standing for 2019-2020')

fig.savefig('C:\\Users\\scher\\school\\senior-thesis\\images\\bp_hist_standing_2019.png')

# %% [markdown]
# The boxplot and histogram both show that `Standing` is extremely skewed to the right -- that most clubs tend to be only a couple years old. We'll see if this trend exists in other years.

# %%
sns.set(rc={'figure.figsize':(20,20)})

# The years we want to plot can be edited by adding to the following array. That said, the figure size (in the line above)
# must be adjusted accordingly.
years = [2017, 2018, 2020]

fig, ax = plt.subplots(len(years),2)

for i, year in enumerate(years):
    data = rso_data[rso_data['Year']==year]
    
    sns.boxplot(x='Standing', data=data, ax=ax[i][0]).set_title(f'Boxplot of Standing for {year}-{year+1}')
    sns.distplot(data['Standing'], bins=np.arange(135), ax=ax[i][1]).set_title(f'Histogram of Standing for {year}-{year+1}')
    
fig.savefig('C:\\Users\\scher\\school\\senior-thesis\\images\\bp_hist_standing_2017_18_20.png')

# %% [markdown]
# Although `Standing` certainly reflects an overall gradual increase over time, RSO standing, in general, is still extremely skewed to the left. This could be attributed to the fact that new clubs are be volatile -- they may only last a few years before being disbanded.
#
# Bins for `Standing` must be created with this in mind.

# %%
# Create bins for every 10th percentile based on budget year, which accounts for specific ASUC guidelines for funding clubs
# with a standing of 3 or lower.
bin_vals_dict = {}

for y in rso_data['Year'].unique():
    data_by_year = rso_data[rso_data['Year']==y]
    bins = np.unique([np.round(np.percentile(data_by_year['Standing'], p)) for p in np.arange(0,100,10)])
    
    bin_vals_dict[y] = bins
    
bin_vals_dict
# Out:
# {2012: array([ 1.,  2.,  3.,  5.,  6.,  8., 12., 14., 20.]),
#  2013: array([ 1.,  2.,  3.,  5.,  7., 10., 14., 18.]),
#  2014: array([ 1.,  2.,  3.,  5.,  8., 10., 14., 19.]),
#  2015: array([ 1.,  2.,  3.,  5.,  8., 10., 15., 20.]),
#  2016: array([ 1.,  2.,  3.,  4.,  6., 10., 14., 20.]),
#  2017: array([ 1.,  2.,  3.,  5.,  7., 10., 14., 21.]),
#  2018: array([ 1.,  2.,  3.,  4.,  5.,  8., 11., 16., 23.]),
#  2019: array([ 1.,  2.,  3.,  4.,  6.,  9., 14., 22.]),
#  2020: array([ 1.,  2.,  3.,  4.,  6.,  9., 14., 22.])}

# %%
def add_standing_bins(row, rso_data, bin_vals_dict):
    year = row['Year']
    standing = row['Standing']
    
    bins_by_year = bin_vals_dict[year]
    bin_num = np.argmin(abs(bins_by_year-standing))
    
    return bin_num

# %%
rso_data['Binned Standing'] = rso_data.apply(lambda r: add_standing_bins(r, rso_data, bin_vals_dict), axis=1)
rso_data
# Out:
#       Year                                Organization  Type  \
# 0     2012                            maganda magazine   PUB
# 1     2012                                     Threads   PUB
# 2     2012                          Alternative Breaks   PUB
# 3     2012                               BARE Magazine   PUB
# 4     2012                     Berkeley Fiction Review   PUB
# ...    ...                                         ...   ...
# 3874  2020  Volunteer Health Interpreters Organization  SISG
# 3875  2020     Volunteer Income Tax Assistance Program  SISG
# 3876  2020     Volunteers Around the World at Berkeley  SISG
# 3877  2020                                 Wonderworks  SISG
# 3878  2020                               You Mean More  SISG
#
#                 Designation  Standing  Allocation  Binned Standing
# 0          Publications RSO        23     1592.02                8
# 1          Publications RSO        12     1300.00                6
# 2               Service RSO        10      891.07                5
# 3          Publications RSO         6     1250.00                4
# 4          Publications RSO        29     1036.99                8
# ...                     ...       ...         ...              ...
# 3874  Health & Wellness RSO        15     4300.00                6
# 3875            Service RSO         8      480.00                5
# 3876            Service RSO         7      250.00                4
# 3877            Service RSO        10        0.00                5
# 3878  Health & Wellness RSO         9     1200.00                5
#
# [3876 rows x 7 columns]

# %% [markdown]
# # Normalization

# %%
norm_rso_data = rso_data.copy(deep=True)

# %% [markdown]
# ## Normalizing values by year

# %%
def y_norm(data, row):
    year = row[['Year']].values[0]
    alloc = row[['Allocation']].values[0]
    
    year_mean = np.mean(data[data['Year'] == year]['Allocation'])
    year_std = np.std(data[data['Year'] == year]['Allocation'])
                      
    return (alloc - year_mean) / year_std

# %%
norm_rso_data['norm_by_y'] = norm_rso_data.apply(lambda r: y_norm(rso_data, r), axis=1)
norm_rso_data
# Out:
#       Year                                Organization  Type  \
# 0     2012                            maganda magazine   PUB
# 1     2012                                     Threads   PUB
# 2     2012                          Alternative Breaks   PUB
# 3     2012                               BARE Magazine   PUB
# 4     2012                     Berkeley Fiction Review   PUB
# ...    ...                                         ...   ...
# 3874  2020  Volunteer Health Interpreters Organization  SISG
# 3875  2020     Volunteer Income Tax Assistance Program  SISG
# 3876  2020     Volunteers Around the World at Berkeley  SISG
# 3877  2020                                 Wonderworks  SISG
# 3878  2020                               You Mean More  SISG
#
#                 Designation  Standing  Allocation  Binned Standing  norm_by_y
# 0          Publications RSO        23     1592.02                8  -0.008281
# 1          Publications RSO        12     1300.00                6  -0.070396
# 2               Service RSO        10      891.07                5  -0.157379
# 3          Publications RSO         6     1250.00                4  -0.081032
# 4          Publications RSO        29     1036.99                8  -0.126341
# ...                     ...       ...         ...              ...        ...
# 3874  Health & Wellness RSO        15     4300.00                6   0.416259
# 3875            Service RSO         8      480.00                5  -0.196901
# 3876            Service RSO         7      250.00                4  -0.233819
# 3877            Service RSO        10        0.00                5  -0.273947
# 3878  Health & Wellness RSO         9     1200.00                5  -0.081331
#
# [3876 rows x 8 columns]

# %% [markdown]
# ## Normalizing values by year and designation

# %%
def yd_norm(data, row):
    year = row[['Year']].values[0]
    desig = row[['Designation']].values[0]
    alloc = row[['Allocation']].values[0]
    
    year_mean = np.mean(data[(data['Year'] == year) 
                             & (data['Designation'] == desig)]
                        ['Allocation'])
    year_std = np.std(data[data['Year'] == year]['Allocation'])
                      
    return (alloc - year_mean) / year_std

# %%
norm_rso_data['norm_by_yd'] = norm_rso_data.apply(lambda r: yd_norm(rso_data, r), axis=1)
norm_rso_data
# Out:
#       Year                                Organization  Type  \
# 0     2012                            maganda magazine   PUB
# 1     2012                                     Threads   PUB
# 2     2012                          Alternative Breaks   PUB
# 3     2012                               BARE Magazine   PUB
# 4     2012                     Berkeley Fiction Review   PUB
# ...    ...                                         ...   ...
# 3874  2020  Volunteer Health Interpreters Organization  SISG
# 3875  2020     Volunteer Income Tax Assistance Program  SISG
# 3876  2020     Volunteers Around the World at Berkeley  SISG
# 3877  2020                                 Wonderworks  SISG
# 3878  2020                               You Mean More  SISG
#
#                 Designation  Standing  Allocation  Binned Standing  norm_by_y  \
# 0          Publications RSO        23     1592.02                8  -0.008281
# 1          Publications RSO        12     1300.00                6  -0.070396
# 2               Service RSO        10      891.07                5  -0.157379
# 3          Publications RSO         6     1250.00                4  -0.081032
# 4          Publications RSO        29     1036.99                8  -0.126341
# ...                     ...       ...         ...              ...        ...
# 3874  Health & Wellness RSO        15     4300.00                6   0.416259
# 3875            Service RSO         8      480.00                5  -0.196901
# 3876            Service RSO         7      250.00                4  -0.233819
# 3877            Service RSO        10        0.00                5  -0.273947
# 3878  Health & Wellness RSO         9     1200.00                5  -0.081331
#
#       norm_by_yd
# 0       0.036367
# 1      -0.025748
# 2      -0.181246
# 3      -0.036383
# 4      -0.081692
# ...          ...
# 3874    0.413214
# 3875   -0.293152
# 3876   -0.330070
# 3877   -0.370198
# 3878   -0.084376
#
# [3876 rows x 9 columns]

# %% [markdown]
# ## Normalize values by year and binned standing

# %%
def ys_norm(data, row):
    year = row[['Year']].values[0]
    standing = row[['Binned Standing']].values[0]
    alloc = row[['Allocation']].values[0]
    
    year_mean = np.mean(data[(data['Year'] == year) 
                             & (data['Binned Standing'] == standing)]
                        ['Allocation'])
    year_std = np.std(data[data['Year'] == year]['Allocation'])
                      
    return (alloc - year_mean) / year_std

# %%
norm_rso_data['norm_by_ys'] = norm_rso_data.apply(lambda r: ys_norm(rso_data, r), axis=1)
norm_rso_data
# Out:
#       Year                                Organization  Type  \
# 0     2012                            maganda magazine   PUB
# 1     2012                                     Threads   PUB
# 2     2012                          Alternative Breaks   PUB
# 3     2012                               BARE Magazine   PUB
# 4     2012                     Berkeley Fiction Review   PUB
# ...    ...                                         ...   ...
# 3874  2020  Volunteer Health Interpreters Organization  SISG
# 3875  2020     Volunteer Income Tax Assistance Program  SISG
# 3876  2020     Volunteers Around the World at Berkeley  SISG
# 3877  2020                                 Wonderworks  SISG
# 3878  2020                               You Mean More  SISG
#
#                 Designation  Standing  Allocation  Binned Standing  norm_by_y  \
# 0          Publications RSO        23     1592.02                8  -0.008281
# 1          Publications RSO        12     1300.00                6  -0.070396
# 2               Service RSO        10      891.07                5  -0.157379
# 3          Publications RSO         6     1250.00                4  -0.081032
# 4          Publications RSO        29     1036.99                8  -0.126341
# ...                     ...       ...         ...              ...        ...
# 3874  Health & Wellness RSO        15     4300.00                6   0.416259
# 3875            Service RSO         8      480.00                5  -0.196901
# 3876            Service RSO         7      250.00                4  -0.233819
# 3877            Service RSO        10        0.00                5  -0.273947
# 3878  Health & Wellness RSO         9     1200.00                5  -0.081331
#
#       norm_by_yd  norm_by_ys
# 0       0.036367   -1.297590
# 1      -0.025748   -0.027429
# 2      -0.181246    0.023276
# 3      -0.036383    0.145864
# 4      -0.081692   -1.415649
# ...          ...         ...
# 3874    0.413214    0.360698
# 3875   -0.293152   -0.234523
# 3876   -0.330070   -0.089844
# 3877   -0.370198   -0.311569
# 3878   -0.084376   -0.118954
#
# [3876 rows x 10 columns]

# %% [markdown]
# ## Normalize values by year, designation, and binned standing

# %%
def yds_norm(data, row):
    year = row[['Year']].values[0]
    desig = row[['Designation']].values[0]
    standing = row[['Binned Standing']].values[0]
    alloc = row[['Allocation']].values[0]
    
    year_mean = np.mean(data[(data['Year'] == year) 
                             & (data['Designation'] == desig) 
                             & (data['Binned Standing'] == standing)]
                        ['Allocation'])
    year_std = np.std(data[data['Year'] == year]['Allocation'])
                      
    return (alloc - year_mean) / year_std

# %%
norm_rso_data['norm_by_yds'] = norm_rso_data.apply(lambda r: yds_norm(rso_data, r), axis=1)
norm_rso_data
# Out:
#       Year                                Organization  Type  \
# 0     2012                            maganda magazine   PUB
# 1     2012                                     Threads   PUB
# 2     2012                          Alternative Breaks   PUB
# 3     2012                               BARE Magazine   PUB
# 4     2012                     Berkeley Fiction Review   PUB
# ...    ...                                         ...   ...
# 3874  2020  Volunteer Health Interpreters Organization  SISG
# 3875  2020     Volunteer Income Tax Assistance Program  SISG
# 3876  2020     Volunteers Around the World at Berkeley  SISG
# 3877  2020                                 Wonderworks  SISG
# 3878  2020                               You Mean More  SISG
#
#                 Designation  Standing  Allocation  Binned Standing  norm_by_y  \
# 0          Publications RSO        23     1592.02                8  -0.008281
# 1          Publications RSO        12     1300.00                6  -0.070396
# 2               Service RSO        10      891.07                5  -0.157379
# 3          Publications RSO         6     1250.00                4  -0.081032
# 4          Publications RSO        29     1036.99                8  -0.126341
# ...                     ...       ...         ...              ...        ...
# 3874  Health & Wellness RSO        15     4300.00                6   0.416259
# 3875            Service RSO         8      480.00                5  -0.196901
# 3876            Service RSO         7      250.00                4  -0.233819
# 3877            Service RSO        10        0.00                5  -0.273947
# 3878  Health & Wellness RSO         9     1200.00                5  -0.081331
#
#       norm_by_yd  norm_by_ys  norm_by_yds
# 0       0.036367   -1.297590     0.045878
# 1      -0.025748   -0.027429    -0.243188
# 2      -0.181246    0.023276    -0.066829
# 3      -0.036383    0.145864     0.000000
# 4      -0.081692   -1.415649    -0.072182
# ...          ...         ...          ...
# 3874    0.413214    0.360698     0.303370
# 3875   -0.293152   -0.234523    -0.045412
# 3876   -0.330070   -0.089844    -0.020064
# 3877   -0.370198   -0.311569    -0.122458
# 3878   -0.084376   -0.118954     0.000000
#
# [3876 rows x 11 columns]

# %%
norm_rso_data.to_csv('C:\\Users\\scher\\school\\senior-thesis\\data\\norm_rso_data.txt')
