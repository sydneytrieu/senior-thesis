# %%
import numpy as np
import pandas as pd
import re

from fuzzywuzzy import process
pd.options.display.max_colwidth = 200

# %% [markdown]
# # Load 2019-2020 final allocations

# %%
final = pd.read_csv('C:\\Users\\scher\\school\\senior-thesis\\data\\rso_data.txt', index_col=0)
final = final[final['Year']==2019].reset_index().drop(columns='index')
final
# Out:
#      Year                     Organization  Type            Designation  \
# 0    2019                       The B-Side   PUB       Publications RSO
# 1    2019                    BARE Magazine   PUB       Publications RSO
# 2    2019         Berkeley Economic Review   PUB           Academic RSO
# 3    2019          Berkeley Fiction Review   PUB       Publications RSO
# 4    2019           Berkeley Poetry Review   PUB       Publications RSO
# ..    ...                              ...   ...                    ...
# 521  2019  Volunteers for Medical Outreach  SISG            Service RSO
# 522  2019                      Wonderworks  SISG            Service RSO
# 523  2019                    You Mean More  SISG  Health & Wellness RSO
# 524  2019        Youth Empowerment Program  SISG            Service RSO
# 525  2019            Youth Support Program  SISG            Service RSO
#
#      Standing  Allocation
# 0           7       350.0
# 1          12      4077.0
# 2           2       700.0
# 3          36      2000.0
# 4          25      1520.0
# ..        ...         ...
# 521         6      2200.0
# 522         9         0.0
# 523         8      1500.0
# 524         6      1850.0
# 525        24       800.0
#
# [526 rows x 6 columns]

# %% [markdown]
# # Load and clean 2019-2020 initial allocations

# %%
initial = pd.read_csv('C:\\Users\\scher\\school\\senior-thesis\\data\\reformatted\\2019-2020_initial.txt', 
                      delimiter='\t',
                      usecols=[1,3,5,7],
                      names=['Organization', 'Type', 'Standing', 'Allocation'])
initial = initial[initial['Type'].isin(['PUB','SAG','SISG'])]
initial['Standing'] = initial['Standing'].apply(int)

def clean_alloc(alloc):
    if alloc == 'Sponsorship Only' or alloc == 'Sponsorship only' or alloc == 'Sponsorsphip Only':
        return 0
    
    alloc = alloc.replace('$','')
    
    if ',' in alloc:
        alloc = alloc.replace(',','')
        
    return float(alloc)

initial['Allocation'] = initial['Allocation'].apply(clean_alloc)

initial
# Out:
#                                 Organization  Type  Standing  Allocation
# 18                               B-Side, The   PUB         7       350.0
# 19                             BARE Magazine   PUB        12      4077.0
# 20                  Berkeley Economic Review   PUB         2       700.0
# 21                   Berkeley Fiction Review   PUB        36      2000.0
# 22                    Berkeley Poetry Review   PUB        25      1520.0
# ..                                       ...   ...       ...         ...
# 490  Volunteers Around the World at Berkeley  SISG         6       200.0
# 491          Volunteers for Medical Outreach  SISG         6      2200.0
# 492                            You Mean More  SISG         8      1500.0
# 493                Youth Empowerment Program  SISG         6      1850.0
# 494                    Youth Support Program  SISG        24       800.0
#
# [477 rows x 4 columns]

# %%
def org_matcher(initial_name, final_df):
    best_match = process.extractOne(initial_name, final_df['Organization'])
    
    best_match_name = best_match[0]
    best_match_score = best_match[1]
    
    if best_match_score == 100:
        return best_match_name
    
    print(f'The initial name is: {initial_name}. \n The closest match is: {best_match_name}.')
    auth = input('authorize match?')
    if auth == 'y':
        return best_match_name
    else:
        return np.nan

# %%
initial['matched_names'] = initial['Organization'].apply(lambda x: org_matcher(x, final))
# Out:
# The initial name is: B-Side, The.
#  The closest match is: The B-Side.
# authorize match?y
# The initial name is: Berkeley Political Review, The.
#  The closest match is: The Berkeley Political Review.
# authorize match?y
# The initial name is: Blue & Gold Yearbook.
#  The closest match is: Blue and Gold Yearbook.
# authorize match?y
# The initial name is: Cal Literature and Arts Magazine.
#  The closest match is: Cal Literature & Arts Magazine.
# authorize match?y
# The initial name is: Intercollegiate Finance Journal at UC Berkeley.
#  The closest match is: Intercollegiate Finance Journal at Berkeley.
# authorize match?y
# The initial name is: Smart Ass, The.
#  The closest match is: The Smart Ass.
# authorize match?y
# The initial name is: threads (formerly known as Al-Bayan).
#  The closest match is: Threads.
# authorize match?y
# The initial name is: American Institute of Architecture Students -UC Berkeley Chapter.
#  The closest match is: American Institute of Architecture Students.
# authorize match?y
# The initial name is: American Medical Student Association-- Berkeley Premedical Chapter.
#  The closest match is: American Medical Student Association--Berkeley Premedical Chapter.
# authorize match?y
# The initial name is: ARC Repertory Theatre.
#  The closest match is: ARC Repertory Theatre (ARC Rep).
# authorize match?y
# The initial name is: Artists in Resonance A Cappella.
#  The closest match is: Artists in Resonance.
# authorize match?y
# The initial name is: Asian American Law Journal Undergraduate Fellows.
#  The closest match is: Asian American Law Journal.
# authorize match?y
# The initial name is: Aurum Cosmetics (Formerly known as Kr�sa Cosmetics Team).
#  The closest match is: Aurum Cosmetics.
# authorize match?y
# The initial name is: Autonomous Underwater Vehicles Team at Berkeley.
#  The closest match is: Berkeley Economic Review.
# authorize match?n
# The initial name is: Berkeley Energy and Resources Collaborative Undergraduate.
#  The closest match is: Berkeley Energy and Resources Collaborative (Graduate group).
# authorize match?n
# The initial name is: Berkeley Legal Studies Organization.
#  The closest match is: Berkeley Legal Studies Association.
# authorize match?y
# The initial name is: Berkeley Opinion.
#  The closest match is: Berkeley Economic Review.
# authorize match?n
# The initial name is: Best Laid Plans Improv.
#  The closest match is: Best Laid Plans.
# authorize match?y
# The initial name is: Black Engineering and Science Student Association.
#  The closest match is: Black Engineering and Science Students Association.
# authorize match?y
# The initial name is: Cal American Institute of Aeronautics and Astronautics.
#  The closest match is: American Institute of Aeronautics and Astronautics.
# authorize match?y
# The initial name is: Cal Black Student Union.
#  The closest match is: Black Student Union.
# authorize match?y
# The initial name is: Cal Queer and Asian.
#  The closest match is: Cal Queer & Asian.
# authorize match?y
# The initial name is: ChunJinAhm.
#  The closest match is: Chun Jin Ahm.
# authorize match?y
# The initial name is: CMG Strategy Consulting (Formerly Creative Marketing Group).
#  The closest match is: CMG Strategy Consulting.
# authorize match?y
# The initial name is: Coalition to Defend Affirmative Action By Any Means Necessary.
#  The closest match is: To An Unknown God.
# authorize match?n
# The initial name is: Collegiate 100 (formerly 100 College Black Men).
#  The closest match is: Collegiate 100.
# authorize match?y
# The initial name is: Delta Xi Phi Multicultural Sorority Inc..
#  The closest match is: Alpha Phi Omega.
# authorize match?n
# The initial name is: Enactus of Berkeley (formely SIFE).
#  The closest match is: Enactus of Berkeley.
# authorize match?y
# The initial name is: Engineers For A Sustainable World - Berkeley.
#  The closest match is: Engineers For A Sustainable World -Berkeley.
# authorize match?y
# The initial name is: Faces of African Muslims.
#  The closest match is: Faces of African Muslims Students.
# authorize match?y
# The initial name is: Gamma Rho Lambda.
#  The closest match is: Future Business Leaders of America-Phi Beta Lambda, Inc..
# authorize match?n
# The initial name is: Gamma Zeta Alpha Fraternity, Inc.
#  The closest match is: Alpha Kappa Psi.
# authorize match?n
# The initial name is: Gates Millennium Scholars Association.
#  The closest match is: American Medical Student Association--Berkeley Premedical Chapter.
# authorize match?n
# The initial name is: Golden Women.
#  The closest match is: American Medical Women's Association at Berkeley.
# authorize match?n
# The initial name is: Indian Students Association (ISA).
#  The closest match is: Indian Students Association.
# authorize match?y
# The initial name is: Kendo Club at Berkeley.
#  The closest match is: Kendo Club.
# authorize match?y
# The initial name is: Koinonia.
#  The closest match is: Koinonia Campus Fellowship.
# authorize match?y
# The initial name is: Korean Christian Biblical and Theological Studies.
#  The closest match is: Korean Christian Biblical & Theological Studies (Originally "BCPC").
# authorize match?y
# The initial name is: Korean-American Scientists and Engineers Association.
#  The closest match is: Korean-American Scientists and Engineers Association (Silicon Valley Chapter).
# authorize match?y
# The initial name is: Latinx Emerging in English.
#  The closest match is: In Color Film and Visual Arts Collective.
# authorize match?n
# The initial name is: Le Cercle Fran�ais of Berkeley.
#  The closest match is: Le Cercle Français of Berkeley.
# authorize match?y
# The initial name is: Molecular and Cell Biology Cell Developmental Neurobiological Association.
#  The closest match is: Molecular and Cell Biology, Cell Developmental, Neurobiological Association.
# authorize match?y
# The initial name is: Movement, The.
#  The closest match is: The Movement.
# authorize match?y
# The initial name is: Next Generation Consulting.
#  The closest match is: Next Generation Consulting at Berkeley.
# authorize match?y
# The initial name is: Peers Espousing Amiability Cooperation and Education.
#  The closest match is: Peers Espousing Amiability, Cooperation, and Education.
# authorize match?y
# The initial name is: Pilipino Association of Scientists, Architects, and Engineers.
#  The closest match is: Pilipinx Association of Scientists, Architects, and Engineers.
# authorize match?y
# The initial name is: Queer + Allied Pre-Health/ Pre-Medical Association.
#  The closest match is: Queer + Allied Pre-Health / Pre-Medical Association.
# authorize match?y
# The initial name is: Sigma Omicron  Pi.
#  The closest match is: Kappa Alpha Pi Pre-Law Fraternity.
# authorize match?n
# The initial name is: Sigma Psi Zeta Sorority, Inc.
#  The closest match is: Alpha Kappa Psi.
# authorize match?n
# The initial name is: Sorayya: Middle Eastern and Central Asian Dance Troupe.
#  The closest match is: Sorayya Middle Eastern and Central Asian Dance Troupe.
# authorize match?y
# The initial name is: Statistics Undergraduate Students Association.
#  The closest match is: Mathematics Undergraduate Student Association.
# authorize match?n
# The initial name is: Team Velocipraptors.
#  The closest match is: Team Velociraptors.
# authorize match?y
# The initial name is: The Bearettes at Berkeley Drill Team.
#  The closest match is: The Bearettes Drill Team at Berkeley.
# authorize match?y
# The initial name is: The Student Immigration Relief Clinic at Berkeley.
#  The closest match is: Student Immigration Relief Clinic at Berkeley.
# authorize match?y
# The initial name is: Undergraduate Legal Honor Society.
#  The closest match is: Undergraduate Legal Honors Society.
# authorize match?y
# The initial name is: Undergraduate Women in Economics.
#  The closest match is: Undergraduate Women in Economics at Berkeley.
# authorize match?y
# The initial name is: Women in Mathematics at Berkeley.
#  The closest match is: Womxn in Mathematics at Berkeley.
# authorize match?y
# The initial name is: 100 STRONG.
#  The closest match is: 100 Strong: Female Mentorship and Leadership Development.
# authorize match?y
# The initial name is: Alpha Kappa Alpha Sorority Inc., Rho Chapter.
#  The closest match is: Alpha Kappa Psi.
# authorize match?n
# The initial name is: Alpha Phi Alpha Fraternity, Inc..
#  The closest match is: Alpha Epsilon Zeta Fraternity, Inc..
# authorize match?n
# The initial name is: American Society for Biochemistry and Molecular Biology at Berkeley.
#  The closest match is: American Society for Biochemistry and Molecular Biology.
# authorize match?n
# The initial name is: Bhagat Puran Singh Health Initiative @ Berkeley.
#  The closest match is: Bhagat Puran Singh Health Initiative at Berkeley.
# authorize match?y
# The initial name is: Cal Berkeley Habitat for Humanity.
#  The closest match is: Cal Habitat for Humanity.
# authorize match?y
# The initial name is: California Health Professional Student Alliance.
#  The closest match is: California Health Professional Student Alliance at UC Berkeley.
# authorize match?y
# The initial name is: Delta Sigma Theta Sorority Incorporated-Kappa Chapter.
#  The closest match is: Alpha Kappa Psi.
# authorize match?n
# The initial name is: Destress With Dogs.
#  The closest match is: De-stress with Dogs.
# authorize match?y
# The initial name is: Greening the Greeks.
#  The closest match is: The B-Side.
# authorize match?n
# The initial name is: Helix@Berkeley.
#  The closest match is: Helix @ Berkeley.
# authorize match?y
# The initial name is: INvent Berkeley.
#  The closest match is: INvent.
# authorize match?y
# The initial name is: Lambda Theta Alpha Latin Sorority, Incorporated.
#  The closest match is: Alpha Kappa Psi.
# authorize match?n
# The initial name is: Lambda Theta Nu Sorority, Inc..
#  The closest match is: Future Business Leaders of America-Phi Beta Lambda, Inc..
# authorize match?n
# The initial name is: Lambda Theta Phi, Latin Fraternity, Inc..
#  The closest match is: Alpha Phi Omega.
# authorize match?n
# The initial name is: Latinx Caucus at the University of California-Berkeley.
#  The closest match is: Latinx Caucus.
# authorize match?y
# The initial name is: MOVE: API Community Organizing Fellowship.
#  The closest match is: MOVE: API Organizing Fellowship.
# authorize match?y
# The initial name is: Omega Phi Beta Sorority, Incorporated.
#  The closest match is: Alpha Phi Omega.
# authorize match?n
# The initial name is: Prioject Vision.
#  The closest match is: Project Vision.
# authorize match?y
# The initial name is: Public Service Internships.
#  The closest match is: Cal Undergraduate Public Health Coalition.
# authorize match?n
# The initial name is: Rising Immigrant Scholars through Education.
#  The closest match is: Rising Immigrant Scholars through Education - RISE.
# authorize match?y
# The initial name is: Sigma Pi Alpha Sorority, Inc..
#  The closest match is: Alpha Kappa Psi.
# authorize match?n
# The initial name is: Thrive Aspire Lead (formerly known as True Asian Leaders).
#  The closest match is: Thrive Aspire Lead.
# authorize match?y
# The initial name is: UNICEF  at Berkeley.
#  The closest match is: UNICEF at Berkeley.
# authorize match?y
# The initial name is: V-Day at Cal.
#  The closest match is: T-Cal.
# authorize match?n
# The initial name is: VIDA Medical Volunteering at Berkeley.
#  The closest match is: VIDA Medical Volunteer.
# authorize match?y
# The initial name is: Volunteer Income Tax Association Program.
#  The closest match is: Volunteer Income Tax Assistance Program.
# authorize match?y

# %%
initial[initial['matched_names'].isna()]
# Out:
#                                           Organization  Type  Standing  \
# 78     Autonomous Underwater Vehicles Team at Berkeley   SAG         3
# 89   Berkeley Energy and Resources Collaborative Un...   SAG         1
# 94                                    Berkeley Opinion   SAG         6
# 141  Coalition to Defend Affirmative Action By Any ...   SAG        21
# 161           Delta Xi Phi Multicultural Sorority Inc.   SAG         3
# 187                                   Gamma Rho Lambda   SAG         3
# 188                   Gamma Zeta Alpha Fraternity, Inc   SAG        11
# 189              Gates Millennium Scholars Association   SAG        13
# 193                                       Golden Women   SAG         3
# 225                         Latinx Emerging in English   SAG         3
# 301                                  Sigma Omicron  Pi   SAG         1
# 302                       Sigma Psi Zeta Sorority, Inc   SAG         4
# 314      Statistics Undergraduate Students Association   SAG         5
# 372       Alpha Kappa Alpha Sorority Inc., Rho Chapter  SISG         3
# 373                   Alpha Phi Alpha Fraternity, Inc.  SISG        17
# 410  Delta Sigma Theta Sorority Incorporated-Kappa ...  SISG        18
# 424                                Greening the Greeks  SISG         7
# 440    Lambda Theta Alpha Latin Sorority, Incorporated  SISG        11
# 441                     Lambda Theta Nu Sorority, Inc.  SISG         9
# 442           Lambda Theta Phi, Latin Fraternity, Inc.  SISG        13
# 453              Omega Phi Beta Sorority, Incorporated  SISG         7
# 460                         Public Service Internships  SISG         1
# 464                      Sigma Pi Alpha Sorority, Inc.  SISG        10
# 485                                       V-Day at Cal  SISG         4
#
#      Allocation matched_names
# 78          0.0           NaN
# 89        200.0           NaN
# 94       1250.0           NaN
# 141      5000.0           NaN
# 161       500.0           NaN
# 187       500.0           NaN
# 188       685.0           NaN
# 189      1000.0           NaN
# 193       500.0           NaN
# 225       500.0           NaN
# 301         0.0           NaN
# 302       245.0           NaN
# 314       900.0           NaN
# 372       600.0           NaN
# 373      3425.0           NaN
# 410      1320.0           NaN
# 424       330.0           NaN
# 440      1500.0           NaN
# 441      1200.0           NaN
# 442      2700.0           NaN
# 453      1000.0           NaN
# 460       500.0           NaN
# 464      1000.0           NaN
# 485       600.0           NaN

# %%
# Drop RSOs that are part of the Panhellenic Council.
# initial = initial.drop([161,187,188,301,302,372,373,410,424,440,441,442,453,460,464])

# %%
initial.at[78, 'matched_names'] = 'Underwater Robotics at Berkeley'
initial.at[89, 'matched_names'] = 'Berkeley Energy and Resources Collaborative (Graduate group)'
initial.at[94, 'matched_names'] = 'BERKOP'
initial.at[141, 'matched_names'] = 'BAMN - Coalition to Defend Affirmative Action, Integration, and Immigrant Rights and Fight for Equality By Any Means Necessary'
initial.at[189, 'matched_names'] = 'Gates Millennium Student Association'
initial.at[193, 'matched_names'] = 'The Golden'
initial.at[225, 'matched_names'] = 'Students of Color Emerging in English'
initial.at[314, 'matched_names'] = 'Student Association for Applied Statistics'
initial.at[485, 'matched_names'] = 'V-Day at Berkeley'

# %%
initial = initial.drop(
    'Organization', axis=1).rename(
    {'matched_names':'Organization'}, axis=1)

# %%
initial = pd.read_csv('C:\\Users\\scher\\school\\senior-thesis\\data\\initial_allocs_2019', index_col=0)

# %%
initial = initial.merge(
    final[['Organization','Designation']], 
    on='Organization')[['Organization', 'Type', 'Designation', 'Standing', 'Allocation']]

# %%
initial.to_csv('C:\\Users\\scher\\school\\senior-thesis\\data\\initial_allocs_2019')

initial
# Out:
#                                 Organization  Type            Designation  \
# 0                                 The B-Side   PUB       Publications RSO
# 1                              BARE Magazine   PUB       Publications RSO
# 2                   Berkeley Economic Review   PUB           Academic RSO
# 3                    Berkeley Fiction Review   PUB       Publications RSO
# 4                     Berkeley Poetry Review   PUB       Publications RSO
# ..                                       ...   ...                    ...
# 457  Volunteers Around the World at Berkeley  SISG            Service RSO
# 458          Volunteers for Medical Outreach  SISG            Service RSO
# 459                            You Mean More  SISG  Health & Wellness RSO
# 460                Youth Empowerment Program  SISG            Service RSO
# 461                    Youth Support Program  SISG            Service RSO
#
#      Standing  Allocation
# 0           7       350.0
# 1          12      4077.0
# 2           2       700.0
# 3          36      2000.0
# 4          25      1520.0
# ..        ...         ...
# 457         6       200.0
# 458         6      2200.0
# 459         8      1500.0
# 460         6      1850.0
# 461        24       800.0
#
# [462 rows x 5 columns]

# %% [markdown]
# # Load and clean list of organizations who requested appeals

# %%
appeals = pd.read_csv('C:\\Users\\scher\\school\\senior-thesis\\data\\appeals_2019.csv', names=['Organization'])
appeals
# Out:
#                                          Organization
# 0   Alpha Phi Alpha Fraternity Inc., Alpha Epsilon...
# 1                                      Toppa@Berkeley
# 2                             Wave Makers of Berkeley
# 3                               Swim Club at Berkeley
# 4              Anti-Trafficking Coalition at Berkeley
# 5           Global Medical Missions Alliance Berkeley
# 6                                        Cal Rotaract
# 7                        Foresight Pre-Optometry Club
# 8                              Cal Berkeley Democrats
# 9   Financial Literacy and Economic Justice Confer...
# 10                                             Dil Se
# 11                                  Ladies for Change
# 12                                       Bears Closet
# 13                              California Mock Trial
# 14                 People's Test Preparation Services
# 15                                          Elections
# 16                   Parliamentary Debate at Berkeley
# 17                                  Natya at Berkeley
# 18         Volunteer Health Interpreters Organization
# 19                          Student Advocate's Office
# 20                       Asha for Education, Berkeley
# 21                              The Heuristic Squelch
# 22                                Black Student Union
# 23                                    Lindy on Sproul
# 24                           Korean Performance Group
# 25                                        Raas Ramzat
# 26                                              CalTV
# 27                                           Koinonia
# 28                                  Phi Delta Epsilon
# 29                                 The Berkeley Forum
# 30                     Berkeley Medical Reserve Corps
# 31        International Relations Council of Berkeley
# 32                  Southeast Asian Student Coalition
# 33                          Jain Students Association
# 34                                         TBD Comedy
# 35     Kidney Disease Screening and Awareness Program
# 36                               South Indian Society
# 37            Bangali Student Association at Berkeley
# 38                       Berkeley College Republicans
# 39                             Blood Pressure Project
# 40                        Indian Students Association
# 41                        threads (formerly al-Bayan)
# 42                                              T-Cal
# 43                   Argentine Tango Club of Berkeley
# 44                   Queer Alliance & Resource Center
# 45                        Berkeley Scientific Journal
# 46               Academic Cultural Enrichment Coaches
# 47                                 Community Projects
# 48                                              ANova
# 49                  Cal Berkeley Habitat for Humanity
# 50                  Engineers and Mentors of Berkeley
# 51                        The Sage Mentorship Project

# %%
appeals['matched_names'] = appeals['Organization'].apply(lambda x: org_matcher(x, final))
# Out:
# The initial name is: Alpha Phi Alpha Fraternity Inc., Alpha Epsilon Chapter.
#  The closest match is: Alpha Epsilon Zeta Fraternity, Inc..
# authorize match?
# The initial name is: Toppa@Berkeley.
#  The closest match is: Toppa at Berkeley.
# authorize match?y
# The initial name is: Global Medical Missions Alliance Berkeley.
#  The closest match is: Global Medical Missions Alliance at Berkeley.
# authorize match?y
# The initial name is: Bears Closet.
#  The closest match is: Bears for Elder Welfare.
# authorize match?
# The initial name is: People's Test Preparation Services.
#  The closest match is: People's Test Preparation Service.
# authorize match?y
# The initial name is: Elections.
#  The closest match is: Berkeley Consulting.
# authorize match?
# The initial name is: Student Advocate's Office.
#  The closest match is: Clio's Scroll.
# authorize match?
# The initial name is: CalTV.
#  The closest match is: T-Cal.
# authorize match?
# The initial name is: Koinonia.
#  The closest match is: Koinonia Campus Fellowship.
# authorize match?y
# The initial name is: TBD Comedy.
#  The closest match is: Health and Medical Apprenticeship Program.
# authorize match?
# The initial name is: threads (formerly al-Bayan).
#  The closest match is: Threads.
# authorize match?y
# The initial name is: Argentine Tango Club of Berkeley.
#  The closest match is: American Chemical Society at Berkeley Student Chapter.
# authorize match?
# The initial name is: Community Projects.
#  The closest match is: Consult Your Community (CYC) at Berkeley.
# authorize match?
# The initial name is: Cal Berkeley Habitat for Humanity.
#  The closest match is: Cal Habitat for Humanity.
# authorize match?y

# %%
appeals
# Out:
#                                               Organization  \
# 0   Alpha Phi Alpha Fraternity Inc., Alpha Epsilon Chapter
# 1                                           Toppa@Berkeley
# 2                                  Wave Makers of Berkeley
# 3                                    Swim Club at Berkeley
# 4                   Anti-Trafficking Coalition at Berkeley
# 5                Global Medical Missions Alliance Berkeley
# 6                                             Cal Rotaract
# 7                             Foresight Pre-Optometry Club
# 8                                   Cal Berkeley Democrats
# 9       Financial Literacy and Economic Justice Conference
# 10                                                  Dil Se
# 11                                       Ladies for Change
# 12                                            Bears Closet
# 13                                   California Mock Trial
# 14                      People's Test Preparation Services
# 15                                               Elections
# 16                        Parliamentary Debate at Berkeley
# 17                                       Natya at Berkeley
# 18              Volunteer Health Interpreters Organization
# 19                               Student Advocate's Office
# 20                            Asha for Education, Berkeley
# 21                                   The Heuristic Squelch
# 22                                     Black Student Union
# 23                                         Lindy on Sproul
# 24                                Korean Performance Group
# 25                                             Raas Ramzat
# 26                                                   CalTV
# 27                                                Koinonia
# 28                                       Phi Delta Epsilon
# 29                                      The Berkeley Forum
# 30                          Berkeley Medical Reserve Corps
# 31             International Relations Council of Berkeley
# 32                       Southeast Asian Student Coalition
# 33                               Jain Students Association
# 34                                              TBD Comedy
# 35          Kidney Disease Screening and Awareness Program
# 36                                    South Indian Society
# 37                 Bangali Student Association at Berkeley
# 38                            Berkeley College Republicans
# 39                                  Blood Pressure Project
# 40                             Indian Students Association
# 41                             threads (formerly al-Bayan)
# 42                                                   T-Cal
# 43                        Argentine Tango Club of Berkeley
# 44                        Queer Alliance & Resource Center
# 45                             Berkeley Scientific Journal
# 46                    Academic Cultural Enrichment Coaches
# 47                                      Community Projects
# 48                                                   ANova
# 49                       Cal Berkeley Habitat for Humanity
# 50                       Engineers and Mentors of Berkeley
# 51                             The Sage Mentorship Project
#
#                                          matched_names
# 0                                                  NaN
# 1                                    Toppa at Berkeley
# 2                              Wave Makers of Berkeley
# 3                                Swim Club at Berkeley
# 4               Anti-Trafficking Coalition at Berkeley
# 5         Global Medical Missions Alliance at Berkeley
# 6                                         Cal Rotaract
# 7                         Foresight Pre-Optometry Club
# 8                               Cal Berkeley Democrats
# 9   Financial Literacy and Economic Justice Conference
# 10                                              Dil Se
# 11                                   Ladies for Change
# 12                                                 NaN
# 13                               California Mock Trial
# 14                   People's Test Preparation Service
# 15                                                 NaN
# 16                    Parliamentary Debate at Berkeley
# 17                                   Natya at Berkeley
# 18          Volunteer Health Interpreters Organization
# 19                                                 NaN
# 20                        Asha for Education, Berkeley
# 21                               The Heuristic Squelch
# 22                                 Black Student Union
# 23                                     Lindy On Sproul
# 24                            Korean Performance Group
# 25                                         Raas Ramzat
# 26                                                 NaN
# 27                          Koinonia Campus Fellowship
# 28                                   Phi Delta Epsilon
# 29                                  The Berkeley Forum
# 30                      Berkeley Medical Reserve Corps
# 31         International Relations Council of Berkeley
# 32                   Southeast Asian Student Coalition
# 33                           Jain Students Association
# 34                                                 NaN
# 35      Kidney Disease Screening and Awareness Program
# 36                                South Indian Society
# 37             Bangali Student Association at Berkeley
# 38                        Berkeley College Republicans
# 39                              Blood Pressure Project
# 40                         Indian Students Association
# 41                                             Threads
# 42                                               T-Cal
# 43                                                 NaN
# 44                    Queer Alliance & Resource Center
# 45                         Berkeley Scientific Journal
# 46                Academic Cultural Enrichment Coaches
# 47                                                 NaN
# 48                                               ANova
# 49                            Cal Habitat for Humanity
# 50                   Engineers and Mentors of Berkeley
# 51                         The Sage Mentorship Project

# %%
appeals[appeals['matched_names'].isna()]
# Out:
#                                               Organization matched_names
# 0   Alpha Phi Alpha Fraternity Inc., Alpha Epsilon Chapter           NaN
# 12                                            Bears Closet           NaN
# 15                                               Elections           NaN
# 19                               Student Advocate's Office           NaN
# 26                                                   CalTV           NaN
# 34                                              TBD Comedy           NaN
# 43                        Argentine Tango Club of Berkeley           NaN
# 47                                      Community Projects           NaN

# %%
appeals = appeals.drop([0,12,15,19,26,34,43,47])

# %%
appeals.to_csv('C:\\Users\\scher\\school\\senior-thesis\\data\\rso_appeals_2019.csv')

# %% [markdown]
# # Compare initial and final allocations

# %%
df = initial.merge(
    final[['Organization','Allocation']], 
    on='Organization').rename({'Allocation_x':'Initial Allocation', 'Allocation_y': 'Final Allocation'}, axis=1)

# %%
df = df.dropna()

# %%
total_initial = sum(df['Initial Allocation'])
total_final = sum(df['Final Allocation'])

print(f'The total initial allocation for RSOs was ${total_initial}, and ${total_final} was the final total.')
print(f'There was a ${total_final - total_initial} difference between the two.')
# Out:
# The total initial allocation for RSOs was $746935.0, and $811806.0 was the final total.
# There was a $64871.0 difference between the two.

# %%
df[df['Initial Allocation'] != df['Final Allocation']]
# Out:
#                                                       Organization  Type  \
# 37                                                 Alpha Phi Omega   SAG
# 44                                              Arab Student Union   SAG
# 52                                    Asha for Education, Berkeley   SAG
# 99                                             Black Student Union   SAG
# 145                                        Disney Club at Berkeley   SAG
# 163                                   Foresight Pre-Optometry Club   SAG
# 178                                    Indian Students Association   SAG
# 250  Pilipinx Association of Scientists, Architects, and Engineers   SAG
# 318                               UC Berkeley Model United Nations   SAG
# 336                                        Wave Makers of Berkeley   SAG
# 354      Asian American and Pacific Islander Health Research Group  SISG
# 358                                        Bears for Elder Welfare  SISG
# 362                                         Berkeley Disaster Team  SISG
# 363                                 Berkeley Medical Reserve Corps  SISG
# 369                           Blueprint, Technology for Nonprofits  SISG
# 392                                               GiANT Filmmakers  SISG
# 403                                          InnoWorks of Berkeley  SISG
# 411                                            Labor Coach Program  SISG
# 412                                              Ladies for Change  SISG
# 423                                 Patient Advocacy Student Group  SISG
# 424                              People's Test Preparation Service  SISG
# 429                               Queer Alliance & Resource Center  SISG
#
#                                    Designation  Standing  Initial Allocation  \
# 37                                 Service RSO        34              2500.0
# 44       Cultural & Identity/International RSO         8               568.0
# 52                                 Service RSO        15               195.0
# 99   Cultural & Identity/Cultural & Ethnic RSO        10               500.0
# 145                           Recreational RSO         2                70.0
# 163                               Academic RSO        28               944.0
# 178      Cultural & Identity/International RSO        16              2781.0
# 250                           Professional RSO        31              2015.0
# 318                               Academic RSO        27              5500.0
# 336                               Academic RSO         2               400.0
# 354                      Health & Wellness RSO         1               165.0
# 358                                Service RSO         7                50.0
# 362                                Service RSO         4               600.0
# 363                      Health & Wellness RSO         6              1586.0
# 369                                Service RSO         1               500.0
# 392                           Media & Film RSO        11               510.0
# 403                                Service RSO         6               275.0
# 411                                Service RSO         9               200.0
# 412     Cultural & Identity/Women Interest RSO         3               290.0
# 423                                Service RSO         8              1500.0
# 424                                Service RSO        23              3000.0
# 429             Cultural & Identity/LGBTQ+ RSO        51             25899.0
#
#      Final Allocation
# 37             4000.0
# 44             1300.0
# 52             1420.0
# 99            25500.0
# 145             400.0
# 163            1175.0
# 178           10000.0
# 250            2100.0
# 318            9200.0
# 336             500.0
# 354             500.0
# 358             400.0
# 362            1000.0
# 363               NaN
# 369            2000.0
# 392            1900.0
# 403            1080.0
# 411            1000.0
# 412             600.0
# 423            3000.0
# 424            6258.0
# 429           40000.0

# %% [markdown]
# # 2018-2019 allocations
