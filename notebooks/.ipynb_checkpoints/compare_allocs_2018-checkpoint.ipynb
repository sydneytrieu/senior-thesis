# %%
import numpy as np
import pandas as pd
import re

from fuzzywuzzy import process
pd.options.display.max_colwidth = 200

# %% [markdown]
# # Load 2018-2019 final allocations

# %%
final = pd.read_csv('C:\\Users\\scher\\school\\senior-thesis\\data\\rso_data_v2.txt', index_col=0)
final = final[final['Year']==2018].reset_index().drop(columns='index')
final
# Out:
#      Year                             Organization  Type  \
# 0    2018                            BARE Magazine   PUB
# 1    2018                  Berkeley Fiction Review   PUB
# 2    2018                   Berkeley Poetry Review   PUB
# 3    2018            The Berkeley Political Review   PUB
# 4    2018                  Berkeley Science Review   PUB
# ..    ...                                      ...   ...
# 418  2018  Volunteer Income Tax Assistance Program  SISG
# 419  2018                              Wonderworks  SISG
# 420  2018                            You Mean More  SISG
# 421  2018                Youth Empowerment Program  SISG
# 422  2018                    Youth Support Program  SISG
#
#                Designation  Standing  Allocation
# 0         Publications RSO        11      3100.0
# 1         Publications RSO        35      1500.0
# 2         Publications RSO        24       500.0
# 3         Publications RSO        17      7000.0
# 4         Publications RSO        18      1000.0
# ..                     ...       ...         ...
# 418            Service RSO         5       600.0
# 419            Service RSO         8       600.0
# 420  Health & Wellness RSO         7      1500.0
# 421            Service RSO         5      1500.0
# 422            Service RSO        23       800.0
#
# [423 rows x 6 columns]

# %% [markdown]
# # Load and clean 2018-2019 initial allocations

# %%
initial = pd.read_csv('C:\\Users\\scher\\school\\senior-thesis\\data\\reformatted\\2018-2019_initial.txt', 
                      delimiter='\t',
                      usecols=[1,3,5,7],
                      names=['Organization', 'Type', 'Standing', 'Allocation'])
initial = initial[initial['Type'].isin(['PUB','SAG','SISG'])]
initial['Standing'] = initial['Standing'].apply(int)

def clean_alloc(alloc):
    if alloc == 'Sponsorship Only' or alloc == 'Sponsorship only' or alloc == 'Sponsorsphip Only':
        return 0
    
    alloc = alloc.replace('$','')
    
    if ',' in alloc:
        alloc = alloc.replace(',','')
        
    return float(alloc)

initial['Allocation'] = initial['Allocation'].apply(clean_alloc)

initial
# Out:
#                                  Organization  Type  Standing  Allocation
# 10                              BARE Magazine   PUB        10      3000.0
# 11                    Berkeley Fiction Review   PUB        34      1500.0
# 12             Berkeley Political Review, The   PUB        16      7000.0
# 13                    Berkeley Science Review   PUB        17      1000.0
# 14             Cal Literature & Arts Magazine   PUB        19      2400.0
# ..                                        ...   ...       ...         ...
# 427  Volunteer Income Tax Association Program  SISG         4       600.0
# 428                               Wonderworks  SISG         7       600.0
# 429                             You Mean More  SISG         6      1500.0
# 430                 Youth Empowerment Program  SISG         4      1500.0
# 431                     Youth Support Program  SISG        22       800.0
#
# [422 rows x 4 columns]

# %%
def org_matcher(initial_name, final_df):
    best_match = process.extractOne(initial_name, final_df['Organization'])
    
    best_match_name = best_match[0]
    best_match_score = best_match[1]
    
    if best_match_score == 100:
        return best_match_name
    
    print(f'The initial name is: {initial_name}. \n The closest match is: {best_match_name}.')
    auth = input('authorize match?')
    if auth == 'y':
        return best_match_name
    else:
        return np.nan

# %%
initial['matched_names'] = initial['Organization'].apply(lambda x: org_matcher(x, final))
# Out:
# The initial name is: Berkeley Political Review, The.
#  The closest match is: The Berkeley Political Review.
# authorize match?y
# The initial name is: Heuristic Squelch, The.
#  The closest match is: The Heuristic Squelch.
# authorize match?y
# The initial name is: Smart Ass, The.
#  The closest match is: The Smart Ass.
# authorize match?y
# The initial name is: The Public Health Advocate.
#  The closest match is: Public Health Advocate.
# authorize match?y
# The initial name is: The Undergraduate Journal of Psychology at Berkeley.
#  The closest match is: Undergraduate Journal of Psychology at Berkeley.
# authorize match?y
# The initial name is: threads (formerly known as Al-Bayan).
#  The closest match is: Threads.
# authorize match?y
# The initial name is: A.S.T.R.O - Astronomer's Society for Teaching, Recreation and Outreach.
#  The closest match is: A.S.T.R.O. - Astronomer's Society for Teaching, Recreation and Outreach.
# authorize match?y
# The initial name is: Alpha Kappa Alpha Sorority, Incorporated.
#  The closest match is: Alpha Kappa Psi.
# authorize match?n
# The initial name is: American Chemical Society Student Chapter at Berkeley.
#  The closest match is: American Chemical Society at Berkeley Student Chapter.
# authorize match?y
# The initial name is: American Chemical Society Student Chapter at Berkeley.
#  The closest match is: American Chemical Society at Berkeley Student Chapter.
# authorize match?y
# The initial name is: Autonomous Underwater Vehicles Team at Berkeley.
#  The closest match is: Berkeley Fiction Review.
# authorize match?n
# The initial name is: Berkeley Energy and Resources Collaborative.
#  The closest match is: Berkeley Energy and Resources Collaborative (Graduate group).
# authorize match?y
# The initial name is: Black Pre-Law Association.
#  The closest match is: Black Pre-Law Association at Berkeley.
# authorize match?y
# The initial name is: Cal Queer and Asian.
#  The closest match is: Cal Queer & Asian.
# authorize match?y
# The initial name is: CalGreeks Programming Council.
#  The closest match is: Amigos.
# authorize match?n
# The initial name is: CMG Strategy Consulting (Formerly Creative Marketing Group).
#  The closest match is: CMG Strategy Consulting.
# authorize match?y
# The initial name is: Coalition to Defend Affirmative Action By Any Means Necessary.
#  The closest match is: To An Unknown God.
# authorize match?n
# The initial name is: Delta Xi Phi Multicultural Sorority Inc..
#  The closest match is: Alpha Phi Omega.
# authorize match?n
# The initial name is: Democratic Education at Cal.
#  The closest match is: Undergraduate Journal of Psychology at Berkeley.
# authorize match?n
# The initial name is: Enactus of Berkeley (formerly SIFE).
#  The closest match is: Enactus of Berkeley.
# authorize match?y
# The initial name is: Fellowship in Christ Berkeley.
#  The closest match is: Fellowship in Christ in Berkeley.
# authorize match?y
# The initial name is: FEM Tech @ Berkeley (Female Empowerment and Mentoring in Tech).
#  The closest match is: Berkeley Fiction Review.
# authorize match?n
# The initial name is: FemSex.
#  The closest match is: GenSex.
# authorize match?y
# The initial name is: Ferments at Berkeley (formerly known as Californium Brewing and Winemaking).
#  The closest match is: Ferments at Berkeley.
# authorize match?y
# The initial name is: Friends of the Coops.
#  The closest match is: Friends of the Co-ops.
# authorize match?y
# The initial name is: Gamma Rho Lambda.
#  The closest match is: Future Business Leaders of America-Phi Beta Lambda, Inc..
# authorize match?n
# The initial name is: Gates Millennium Scholars Association.
#  The closest match is: American Medical Student Association--Berkeley Premedical Chapter.
# authorize match?n
# The initial name is: Golden Bear Competitive Bhangra.
#  The closest match is: Cal Bhangra.
# authorize match?y
# The initial name is: Golden Women.
#  The closest match is: American Medical Women's Association at Berkeley.
# authorize match?n
# The initial name is: Horn of Africa Student Association.
#  The closest match is: Mechanism of Feeling.
# authorize match?n
# The initial name is: Indian Students Association (ISA).
#  The closest match is: Indian Students Association.
# authorize match?y
# The initial name is: Iranian Students Cultural Organization (ISCO).
#  The closest match is: Iranian Students Cultural Organization.
# authorize match?y
# The initial name is: Jugger at Berkeley formerly known as Juggers of the Seven Regents.
#  The closest match is: Jugger at Berkeley.
# authorize match?y
# The initial name is: Korean American Scientists and Engineers Association.
#  The closest match is: Korean-American Scientists and Engineers Association (Silicon Valley Chapter).
# authorize match?y
# The initial name is: Latinx Emerging in English.
#  The closest match is: Creative Applications to Life in Origami.
# authorize match?n
# The initial name is: Latinx Pre-Law Society (formerly known as the Latino Pre-Law Society).
#  The closest match is: Latinx Pre-Law Society.
# authorize match?y
# The initial name is: Le Cercle Fran̤ais of Berkeley.
#  The closest match is: Le Cercle Français of Berkeley.
# authorize match?y
# The initial name is: Liberty in North Korea Berkeley Chapter.
#  The closest match is: Liberty in North Korea at Berkeley.
# authorize match?y
# The initial name is: Magic Club, The.
#  The closest match is: The Magic Club.
# authorize match?y
# The initial name is: Material Science and Engineering Association.
#  The closest match is: Materials Science and Engineering Association.
# authorize match?y
# The initial name is: Mathematics Undergraduate Students Association.
#  The closest match is: Mathematics Undergraduate Student Association.
# authorize match?y
# The initial name is: Mind Body Nutrition Students for Integrative and Preventative Medicine.
#  The closest match is: Mind Body Nutrition: Students for Integrative and Preventive Medicine.
# authorize match?y
# The initial name is: Molecular and Cell Biology Cell Developmental Neurobiological Association.
#  The closest match is: Molecular and Cell Biology, Cell Developmental, Neurobiological Association.
# authorize match?y
# The initial name is: Movement, The.
#  The closest match is: The Movement.
# authorize match?y
# The initial name is: Organization of African Students.
#  The closest match is: Organization of African Students at Berkeley.
# authorize match?y
# The initial name is: Pilipino Association of Scientists, Architects, and Engineers.
#  The closest match is: Pilipinx Association of Scientists, Architects, and Engineers.
# authorize match?y
# The initial name is: Pre-Pharmacy Informational, Learning, & Leadership Society.
#  The closest match is: Pre-Pharmacy Informational, Learning and Leadership Society.
# authorize match?y
# The initial name is: Queer + Allied Pre-Health/Pre-medical Association.
#  The closest match is: Queer + Allied Pre-Health / Pre-Medical Association.
# authorize match?y
# The initial name is: Rising Immigrants Scholars through Education.
#  The closest match is: Rising Immigrant Scholars through Education - RISE.
# authorize match?y
# The initial name is: Sikh Student Association.
#  The closest match is: Sikh Students Association.
# authorize match?y
# The initial name is: Smart Woman Securities at UCBerkeley.
#  The closest match is: Smart Woman Securities at Berkeley.
# authorize match?y
# The initial name is: Statistics Undergraduate Students Association (formerly Undergraduate Statistics Association at Berkeley).
#  The closest match is: Berkeley Fiction Review.
# authorize match?n
# The initial name is: Stock Trading at Berkeley.
#  The closest match is: Stock Trading Crew of Berkeley.
# authorize match?y
# The initial name is: Strait Talk Berkeley.
#  The closest match is: Strait Talk.
# authorize match?y
# The initial name is: Students for Social Change.
#  The closest match is: A.S.T.R.O. - Astronomer's Society for Teaching, Recreation and Outreach.
# authorize match?n
# The initial name is: T.I.n.Y Chinese Theatre Group.
#  The closest match is: T.I.n.Y. Chinese Theatre Group.
# authorize match?y
# The initial name is: Tennis at Cal.
#  The closest match is: Cal Literature & Arts Magazine.
# authorize match?n
# The initial name is: The Berkeley Think Tank.
#  The closest match is: Think Tank of Berkeley.
# authorize match?y
# The initial name is: The Student Immigration Relief Clinic at Berkeley.
#  The closest match is: Student Immigration Relief Clinic at Berkeley.
# authorize match?y
# The initial name is: UC Berkeley Chi Epsilon.
#  The closest match is: Undergraduate Journal of Psychology at Berkeley.
# authorize match?n
# The initial name is: ULAB: Undergraduate Laboratory at Berkeley.
#  The closest match is: Undergraduate Laboratory at Berkeley.
# authorize match?y
# The initial name is: Women in Mathematics at Berkeley.
#  The closest match is: Womxn in Mathematics at Berkeley.
# authorize match?y
# The initial name is: 100 STRONG.
#  The closest match is: 100 Strong: Female Mentorship and Leadership Development.
# authorize match?y
# The initial name is: Alpha Phi Alpha Fraternity, Inc..
#  The closest match is: Alpha Kappa Psi.
# authorize match?n
# The initial name is: ASUC Renters' Legal Assistance.
#  The closest match is: Renters' Legal Assistance.
# authorize match?y
# The initial name is: Berkeley Cambodian Student Association.
#  The closest match is: Berkeley Cambodian Students Association.
# authorize match?y
# The initial name is: Berkeley Disaster Team [Formerly Berkeley Disaster Response Team].
#  The closest match is: Berkeley Disaster Team.
# authorize match?y
# The initial name is: Berkeley Engineers and Mentors.
#  The closest match is: Engineers and Mentors of Berkeley.
# authorize match?y
# The initial name is: Cal Berkeley Habitat for Humanity.
#  The closest match is: Cal Habitat for Humanity.
# authorize match?y
# The initial name is: California Health Professional Student Alliance.
#  The closest match is: California Health Professional Student Alliance at UC Berkeley.
# authorize match?y
# The initial name is: Central Americans for Empowerment.
#  The closest match is: Central Americans for Empowerment at Berkeley.
# authorize match?y
# The initial name is: Confi at Cal.
#  The closest match is: Confi.
# authorize match?y
# The initial name is: Delta Sigma Theta Sorority, Incorporated - Kappa Chapter.
#  The closest match is: Alpha Kappa Psi.
# authorize match?n
# The initial name is: Gamma Zeta Alpha Fraternity, Inc..
#  The closest match is: Alpha Kappa Psi.
# authorize match?n
# The initial name is: Global Social Innovation Initiative at Berkeley, The.
#  The closest match is: The Global Social Innovation Initiative at Berkeley.
# authorize match?y
# The initial name is: Indigenous and Native Coalition Recruitment and Retention Center.
#  The closest match is: Indigenous and Native Coalition (INC) Recruitment and Retention Center.
# authorize match?y
# The initial name is: Jakara Movement Club.
#  The closest match is: Jakara Movement Club at Berkeley.
# authorize match?y
# The initial name is: Lambda Theta Nu Sorority, Inc..
#  The closest match is: Future Business Leaders of America-Phi Beta Lambda, Inc..
# authorize match?n
# The initial name is: Lambda Theta Phi, Latin Fraternity, Inc..
#  The closest match is: Alpha Phi Omega.
# authorize match?n
# The initial name is: Laotian American Student Representation.
#  The closest match is: Laotian American Student Representatives.
# authorize match?y
# The initial name is: Let's Rise- Asian Mentorship Program.
#  The closest match is: Let's Rise - Asian Mentorship Program.
# authorize match?y
# The initial name is: Mixed Student Union.
#  The closest match is: Student Journal of Middle Eastern Studies.
# authorize match?n
# The initial name is: Multi-Cultural Greek Council.
#  The closest match is: International Relations Council of Berkeley.
# authorize match?n
# The initial name is: National Pan-Hellenic Council.
#  The closest match is: National Council of Negro Women.
# authorize match?n
# The initial name is: Ra�_ces Recruitment and Retention Center (formerly Raza Recruitment and Retention Center).
#  The closest match is: American Institute of Aeronautics and Astronautics.
# authorize match?n
# The initial name is: Sigma Gamma Rho Sorority, Inc.
#  The closest match is: Delta Sigma Pi.
# authorize match?n
# The initial name is: Sigma Pi Alpha Sorority, Inc..
#  The closest match is: Alpha Kappa Psi.
# authorize match?n
# The initial name is: Spectrum: Autism at Cal (Formerly known as Autism Speaks U at Berkeley).
#  The closest match is: Spectrum: Autism at Cal.
# authorize match?y
# The initial name is: Thrive Aspire Lead (formerly known as True Asian Leaders).
#  The closest match is: Thrive Aspire Lead.
# authorize match?y
# The initial name is: UC Berkeley Public Service Center.
#  The closest match is: Berkeley Poetry Review.
# authorize match?n
# The initial name is: Volunteer Income Tax Association Program.
#  The closest match is: Volunteer Income Tax Assistance Program.
# authorize match?y

# %%
initial[initial['matched_names'].isna()]
# Out:
#                                                                                                   Organization  \
# 40                                                                    Alpha Kappa Alpha Sorority, Incorporated
# 59                                                             Autonomous Underwater Vehicles Team at Berkeley
# 95                                                                               CalGreeks Programming Council
# 106                                              Coalition to Defend Affirmative Action By Any Means Necessary
# 123                                                                   Delta Xi Phi Multicultural Sorority Inc.
# 124                                                                                Democratic Education at Cal
# 144                                             FEM Tech @ Berkeley (Female Empowerment and Mentoring in Tech)
# 156                                                                                           Gamma Rho Lambda
# 157                                                                      Gates Millennium Scholars Association
# 160                                                                                               Golden Women
# 165                                                                         Horn of Africa Student Association
# 192                                                                                 Latinx Emerging in English
# 268  Statistics Undergraduate Students Association (formerly Undergraduate Statistics Association at Berkeley)
# 277                                                                                 Students for Social Change
# 284                                                                                              Tennis at Cal
# 294                                                                                    UC Berkeley Chi Epsilon
# 315                                                                           Alpha Phi Alpha Fraternity, Inc.
# 351                                                   Delta Sigma Theta Sorority, Incorporated - Kappa Chapter
# 357                                                                          Gamma Zeta Alpha Fraternity, Inc.
# 375                                                                             Lambda Theta Nu Sorority, Inc.
# 376                                                                   Lambda Theta Phi, Latin Fraternity, Inc.
# 382                                                                                        Mixed Student Union
# 384                                                                               Multi-Cultural Greek Council
# 386                                                                              National Pan-Hellenic Council
# 400                  Ra�_ces Recruitment and Retention Center (formerly Raza Recruitment and Retention Center)
# 402                                                                              Sigma Gamma Rho Sorority, Inc
# 403                                                                              Sigma Pi Alpha Sorority, Inc.
# 419                                                                          UC Berkeley Public Service Center
#
#      Type  Standing  Allocation matched_names
# 40    SAG         1       400.0           NaN
# 59    SAG         1         0.0           NaN
# 95    SAG         2       500.0           NaN
# 106   SAG        19      3500.0           NaN
# 123   SAG         1       500.0           NaN
# 124   SAG        36      4500.0           NaN
# 144   SAG         1       400.0           NaN
# 156   SAG         1       400.0           NaN
# 157   SAG        11       950.0           NaN
# 160   SAG         1       400.0           NaN
# 165   SAG         4       163.0           NaN
# 192   SAG         1       400.0           NaN
# 268   SAG         3       500.0           NaN
# 277   SAG         1       400.0           NaN
# 284   SAG         1         0.0           NaN
# 294   SAG         1         0.0           NaN
# 315  SISG        15       224.0           NaN
# 351  SISG        16      2500.0           NaN
# 357  SISG         9      1000.0           NaN
# 375  SISG         7       450.0           NaN
# 376  SISG        11      2100.0           NaN
# 382  SISG        20       500.0           NaN
# 384  SISG         3       600.0           NaN
# 386  SISG         4       500.0           NaN
# 400  SISG        40     40000.0           NaN
# 402  SISG         3       400.0           NaN
# 403  SISG         8       700.0           NaN
# 419  SISG        49         0.0           NaN

# %%
# Drop RSOs that are either part of the Panhellenic Council or are currently an ASUC sponsored organization.
# initial = initial.drop([40,95,123,124,156,315,351,357,375,376,384,386,402,403,419])

# %%
initial.at[59, 'matched_names'] = 'Underwater Robotics at Berkeley'
initial.at[106, 'matched_names'] = 'BAMN - Coalition to Defend Affirmative Action, Integration, and Immigrant Rights and Fight for Equality By Any Means Necessary'
initial.at[144, 'matched_names'] = 'FEMTech'
initial.at[157, 'matched_names'] = 'Gates Millennium Student Association'
initial.at[160, 'matched_names'] = 'The Golden'
initial.at[165, 'matched_names'] = 'Somali, Ethiopian, Eritrean, South Sudanese, Sudanese Association (SEE§A)'
initial.at[192, 'matched_names'] = 'Students of Color Emerging in English'
initial.at[268, 'matched_names'] = 'Student Association for Applied Statistics'
initial.at[277, 'matched_names'] = 'Speak Out Now'
initial.at[284, 'matched_names'] = 'Berkeley Tennis Association'
initial.at[294, 'matched_names'] = 'Chi Epsilon - Civil Engineering Honor Society'
initial.at[382, 'matched_names'] = 'Mixed @ Berkeley Recruitment and Retention Center - MRRC'
initial.at[400, 'matched_names'] = 'Raíces Recruitment and Retention Center'

# %%
initial = initial.drop(
    'Organization', axis=1).rename(
    {'matched_names':'Organization'}, axis=1)

# %%
initial = initial.merge(
    final[['Organization','Designation']], 
    on='Organization')[['Organization', 'Type', 'Designation', 'Standing', 'Allocation']]

# %%
initial.to_csv('C:\\Users\\scher\\school\\senior-thesis\\data\\initial_allocs_2018.csv')

initial
# Out:
#                                 Organization  Type            Designation  \
# 0                              BARE Magazine   PUB       Publications RSO
# 1                    Berkeley Fiction Review   PUB       Publications RSO
# 2              The Berkeley Political Review   PUB       Publications RSO
# 3                    Berkeley Science Review   PUB       Publications RSO
# 4             Cal Literature & Arts Magazine   PUB       Publications RSO
# ..                                       ...   ...                    ...
# 406  Volunteer Income Tax Assistance Program  SISG            Service RSO
# 407                              Wonderworks  SISG            Service RSO
# 408                            You Mean More  SISG  Health & Wellness RSO
# 409                Youth Empowerment Program  SISG            Service RSO
# 410                    Youth Support Program  SISG            Service RSO
#
#      Standing  Allocation
# 0          10      3000.0
# 1          34      1500.0
# 2          16      7000.0
# 3          17      1000.0
# 4          19      2400.0
# ..        ...         ...
# 406         4       600.0
# 407         7       600.0
# 408         6      1500.0
# 409         4      1500.0
# 410        22       800.0
#
# [406 rows x 5 columns]

# %% [markdown]
# # Compare initial and final allocations

# %%
initial = pd.read_csv('C:\\Users\\scher\\school\\senior-thesis\\data\\initial_allocs_2018.csv', index_col=0)

# %%
df = initial.merge(
    final[['Organization','Standing','Allocation']], 
    how='outer',
    on='Organization').drop(
    'Standing_x', axis=1).rename(
    {'Standing_y':'Standing', 'Allocation_x':'Initial Allocation', 'Allocation_y': 'Final Allocation'}, axis=1)

# Drop duplicates
df = df.drop([177,178,180])

df
# Out:
#                        Organization Type       Designation  \
# 0                     BARE Magazine  PUB  Publications RSO
# 1           Berkeley Fiction Review  PUB  Publications RSO
# 2     The Berkeley Political Review  PUB  Publications RSO
# 3           Berkeley Science Review  PUB  Publications RSO
# 4    Cal Literature & Arts Magazine  PUB  Publications RSO
# ..                              ...  ...               ...
# 420         Songwriting at Berkeley  NaN               NaN
# 421              Speech at Berkeley  NaN               NaN
# 422                           SPIRE  NaN               NaN
# 423              REACT! at Berkeley  NaN               NaN
# 424     The Sage Mentorship Project  NaN               NaN
#
#      Initial Allocation  Standing  Final Allocation
# 0                3000.0        11            3100.0
# 1                1500.0        35            1500.0
# 2                7000.0        17            7000.0
# 3                1000.0        18            1000.0
# 4                2400.0        27            2400.0
# ..                  ...       ...               ...
# 420                 NaN         2             100.0
# 421                 NaN         6             150.0
# 422                 NaN         4             150.0
# 423                 NaN         3             400.0
# 424                 NaN         6             300.0
#
# [422 rows x 6 columns]

# %%
total_initial = sum(df['Initial Allocation'].fillna(0))
total_final = sum(df['Final Allocation'].fillna(0))

print(f'The total initial allocation for RSOs was ${total_initial}, and ${total_final} was the final total.')
print(f'There was a ${total_final - total_initial} difference between the two.')
# Out:
# The total initial allocation for RSOs was $776186.0, and $792676.0 was the final total.
# There was a $16490.0 difference between the two.

# %%
compare_df = df.dropna()
compare_df['Allocation Diff'] = compare_df['Final Allocation'] - compare_df['Initial Allocation']

compare_df
# Out:
# C:\Users\scher\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                 Organization  Type            Designation  \
# 0                              BARE Magazine   PUB       Publications RSO
# 1                    Berkeley Fiction Review   PUB       Publications RSO
# 2              The Berkeley Political Review   PUB       Publications RSO
# 3                    Berkeley Science Review   PUB       Publications RSO
# 4             Cal Literature & Arts Magazine   PUB       Publications RSO
# ..                                       ...   ...                    ...
# 405  Volunteer Income Tax Assistance Program  SISG            Service RSO
# 406                              Wonderworks  SISG            Service RSO
# 407                            You Mean More  SISG  Health & Wellness RSO
# 408                Youth Empowerment Program  SISG            Service RSO
# 409                    Youth Support Program  SISG            Service RSO
#
#      Initial Allocation  Standing  Final Allocation  Allocation Diff
# 0                3000.0        11            3100.0            100.0
# 1                1500.0        35            1500.0              0.0
# 2                7000.0        17            7000.0              0.0
# 3                1000.0        18            1000.0              0.0
# 4                2400.0        27            2400.0              0.0
# ..                  ...       ...               ...              ...
# 405               600.0         5             600.0              0.0
# 406               600.0         8             600.0              0.0
# 407              1500.0         7            1500.0              0.0
# 408              1500.0         5            1500.0              0.0
# 409               800.0        23             800.0              0.0
#
# [407 rows x 7 columns]

# %%
diff_allocs = compare_df[compare_df['Allocation Diff'] != 0]
diff_allocs
# Out:
#                                                                Organization  \
# 0                                                             BARE Magazine
# 10                                                     Perspective Magazine
# 17                                                   Public Health Advocate
# 39                                                       Arab Student Union
# 64                                   Black Recruitment and Retention Center
# 65                                                      Black Student Union
# 80                                                        Cal Queer & Asian
# 81                                                                Cal Taiko
# 84                                                                  CalSlam
# 104                                                               Danceworx
# 107                                              Debate Society of Berkeley
# 185                                                         Lindy On Sproul
# 211                                        Parliamentary Debate at Berkeley
# 216                                                         Phi Alpha Theta
# 221                                 Pilipino Association for Health Careers
# 237                               Re-entry and Transfer Student Association
# 282                                        UC Berkeley Model United Nations
# 306                                               Renters' Legal Assistance
# 310                                                 Bears for Elder Welfare
# 317                        Bhagat Puran Singh Health Initiative at Berkeley
# 319                                   bridges Multicultural Resource Center
# 352  Indigenous and Native Coalition (INC) Recruitment and Retention Center
# 353                                                   InnoWorks of Berkeley
# 364           Middle Eastern North African Recruitment and Retention Center
# 365                Mixed @ Berkeley Recruitment and Retention Center - MRRC
# 372                                       People's Test Preparation Service
# 373                                      Pilipinx Academic Student Services
# 380                                        Queer Alliance & Resource Center
# 381                                 Raíces Recruitment and Retention Center
# 382          REACH! Asian Pacific American Recruitment and Retention Center
# 388                                                         Suitcase Clinic
# 393                                                    The Berkeley Project
#
#      Type                                Designation  Initial Allocation  \
# 0     PUB                           Publications RSO              3000.0
# 10    PUB                           Publications RSO              3500.0
# 17    PUB                           Publications RSO              1100.0
# 39    SAG      Cultural & Identity/International RSO               900.0
# 64    SAG                              Sponsored RSO             45000.0
# 65    SAG  Cultural & Identity/Cultural & Ethnic RSO               500.0
# 80    SAG             Cultural & Identity/LGBTQ+ RSO              1100.0
# 81    SAG                        Performing Arts RSO              2000.0
# 84    SAG                        Performing Arts RSO               600.0
# 104   SAG                        Performing Arts RSO              3000.0
# 107   SAG                               Academic RSO               500.0
# 185   SAG                        Performing Arts RSO              1100.0
# 211   SAG                               Academic RSO              2000.0
# 216   SAG                               Academic RSO               125.0
# 221   SAG                           Professional RSO              2500.0
# 237   SAG                                Service RSO              1000.0
# 282   SAG                               Academic RSO              8900.0
# 306  SISG                                Service RSO               200.0
# 310  SISG                                Service RSO               125.0
# 317  SISG                      Health & Wellness RSO               500.0
# 319  SISG                              Sponsored RSO             10000.0
# 352  SISG                              Sponsored RSO              9000.0
# 353  SISG                                Service RSO               600.0
# 364  SISG                              Sponsored RSO              1000.0
# 365  SISG                              Sponsored RSO               500.0
# 372  SISG                                Service RSO              3050.0
# 373  SISG                              Sponsored RSO             33600.0
# 380  SISG             Cultural & Identity/LGBTQ+ RSO             18000.0
# 381  SISG                              Sponsored RSO             40000.0
# 382  SISG                              Sponsored RSO             20000.0
# 388  SISG                                Service RSO             11000.0
# 393  SISG                                Service RSO               100.0
#
#      Standing  Final Allocation  Allocation Diff
# 0          11            3100.0            100.0
# 10         21            3900.0            400.0
# 17         14            1200.0            100.0
# 39          7            1300.0            400.0
# 64         36           40500.0          -4500.0
# 65          9           15500.0          15000.0
# 80          9            1995.0            895.0
# 81         14            2900.0            900.0
# 84         14             800.0            200.0
# 104        22            3400.0            400.0
# 107         7             600.0            100.0
# 185         8            1200.0            100.0
# 211         9            2100.0            100.0
# 216        14             250.0            125.0
# 221        26            3000.0            500.0
# 237        21            1300.0            300.0
# 282        26            9200.0            300.0
# 306        36             400.0            200.0
# 310         7             325.0            200.0
# 317         4             600.0            100.0
# 319        22            9000.0          -1000.0
# 352        26            8100.0           -900.0
# 353         5             700.0            100.0
# 364         5             900.0           -100.0
# 365        21             450.0            -50.0
# 372        22            3500.0            450.0
# 373        34           30240.0          -3360.0
# 380        50           25000.0           7000.0
# 381        41           36000.0          -4000.0
# 382        22           18000.0          -2000.0
# 388        20           11500.0            500.0
# 393        12             500.0            400.0

# %%
grouped_allocs = diff_allocs.groupby('Designation').mean()
grouped_allocs['Number of Orgs'] = diff_allocs.groupby('Designation').size()
grouped_allocs = grouped_allocs[['Standing','Initial Allocation','Final Allocation','Allocation Diff','Number of Orgs']]
grouped_allocs
# Out:
#                                             Standing  Initial Allocation  \
# Designation
# Academic RSO                               14.000000         2881.250000
# Cultural & Identity/Cultural & Ethnic RSO   9.000000          500.000000
# Cultural & Identity/International RSO       7.000000          900.000000
# Cultural & Identity/LGBTQ+ RSO             29.500000         9550.000000
# Health & Wellness RSO                       4.000000          500.000000
# Performing Arts RSO                        14.500000         1675.000000
# Professional RSO                           26.000000         2500.000000
# Publications RSO                           15.333333         2533.333333
# Service RSO                                17.571429         2296.428571
# Sponsored RSO                              25.875000        19887.500000
#
#                                            Final Allocation  Allocation Diff  \
# Designation
# Academic RSO                                    3037.500000       156.250000
# Cultural & Identity/Cultural & Ethnic RSO      15500.000000     15000.000000
# Cultural & Identity/International RSO           1300.000000       400.000000
# Cultural & Identity/LGBTQ+ RSO                 13497.500000      3947.500000
# Health & Wellness RSO                            600.000000       100.000000
# Performing Arts RSO                             2075.000000       400.000000
# Professional RSO                                3000.000000       500.000000
# Publications RSO                                2733.333333       200.000000
# Service RSO                                     2603.571429       307.142857
# Sponsored RSO                                  17898.750000     -1988.750000
#
#                                            Number of Orgs
# Designation
# Academic RSO                                            4
# Cultural & Identity/Cultural & Ethnic RSO               1
# Cultural & Identity/International RSO                   1
# Cultural & Identity/LGBTQ+ RSO                          2
# Health & Wellness RSO                                   1
# Performing Arts RSO                                     4
# Professional RSO                                        1
# Publications RSO                                        3
# Service RSO                                             7
# Sponsored RSO                                           8
